# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Fruits Object detection
# Out:
# /content/drive/MyDrive/Fruits Object detection

# %%
pwd
# Out:
# '/content/drive/MyDrive/Fruits Object detection'

# %%
import glob
import os
import pickle
import xml.etree.ElementTree as ET
from os import listdir, getcwd
from os.path import join

dirs = ['test', 'train']
classes = ['apple', 'banana', 'orange']


def getImagesInDir(dir_path):
    image_list = []
    for filename in glob.glob(dir_path + '/*.jpg'):
        image_list.append(filename)

    return image_list

def convert(size, box):
    dw = 1./(size[0]+0.0001)
    dh = 1./(size[1]+0.0001)
    x = (box[0] + box[1])/2.0 - 1
    y = (box[2] + box[3])/2.0 - 1
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x*dw
    w = w*dw
    y = y*dh
    h = h*dh
    return (x,y,w,h)

def convert_annotation(dir_path, output_path, image_path):
    basename = os.path.basename(image_path)
    basename_no_ext = os.path.splitext(basename)[0]

    in_file = open(dir_path + '/' + basename_no_ext + '.xml')
    out_file = open(output_path + basename_no_ext + '.txt', 'w')
    tree = ET.parse(in_file)
    root = tree.getroot()
    size = root.find('size')
    w = int(size.find('width').text)
    h = int(size.find('height').text)
    if w or h == 0:
        img = cv2.imread(image_path)
        h,w,_ = img.shape

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in classes or int(difficult)==1:
            continue
        cls_id = classes.index(cls)
        xmlbox = obj.find('bndbox')
        b = (float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text))
        bb = convert((w,h), b)
        out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')

cwd = getcwd()
print('not working')
for dir_path in dirs:
    full_dir_path = cwd + '/' + dir_path
    output_path = full_dir_path +'/yolo/'

    if not os.path.exists(output_path):
        print(output_path)
        os.makedirs(output_path)

    image_paths = getImagesInDir(full_dir_path)
    list_file = open(full_dir_path + '.txt', 'w')

    for image_path in image_paths:
        print(image_path)
        list_file.write(image_path + '\n')
        convert_annotation(full_dir_path, output_path, image_path)
    list_file.close()

    print("Finished processing: " + dir_path)
print('this is fun')
# Out:
# not working
# /content/drive/MyDrive/Fruits Object detection/test/yolo/
# /content/drive/MyDrive/Fruits Object detection/test/apple_79.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_77.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_78.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_78.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_79.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_95.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_85.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_92.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_88.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_80.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_80.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_83.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_93.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_81.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_89.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_86.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_87.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_81.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_82.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_82.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_83.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_77.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_84.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_90.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_85.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_91.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_84.jpg
# /content/drive/MyDrive/Fruits Object detection/test/apple_94.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_94.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_88.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_82.jpg
# /content/drive/MyDrive/Fruits Object detection/test/mixed_25.jpg
# /content/drive/MyDrive/Fruits Object detection/test/mixed_23.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_86.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_89.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_80.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_92.jpg
# /content/drive/MyDrive/Fruits Object detection/test/mixed_24.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_81.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_78.jpg
# /content/drive/MyDrive/Fruits Object detection/test/mixed_21.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_91.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_79.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_93.jpg
# /content/drive/MyDrive/Fruits Object detection/test/mixed_22.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_85.jpg
# /content/drive/MyDrive/Fruits Object detection/test/banana_87.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_84.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange_83.jpg
# /content/drive/MyDrive/Fruits Object detection/test/orange